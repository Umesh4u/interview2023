# %%
import pandas as pd

# %%
df = pd.read_csv("/home/umesh/Downloads/example_for_ARP_match/172.29.11.20_22")

# %%
df.shape
# Out:
# (3369, 1)

# %%
df.tail(100)
# Out:
#                                                                                                 Header length: 484
# Time remaining: 94 seconds          NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN                NaN
# Hold Time: 120 seconds              NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN                NaN
# System Capabilities: R              NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN                NaN
# Enabled Capabilities: R             NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN                NaN
# Management Addresses:               NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN                NaN
# ...                                                                                                            ...
# Enabled Capabilities: R             NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN                NaN
# ...
